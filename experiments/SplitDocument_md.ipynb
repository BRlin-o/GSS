# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader
from langchain_core.documents import Document
from langchain_text_splitters import MarkdownHeaderTextSplitter, MarkdownTextSplitter

markdown_path = "../documents/CrossOver/CrossOver.md"
loader = UnstructuredMarkdownLoader(markdown_path)

data = loader.load()
data
# Out:
# [Document(page_content='Gogoro Crossover 系列 Smartscooter® 智慧電動機車 使用手冊\n\n發佈日期:2023.12.11 適用車款:\nCrossOver CrossOver S\niQ System® 版本:6.8.2 以後 Gogoro® App 版本:3.2 以後 製造商:睿能創意股份有限公司 地址:桃園市龜山區頂湖路 33 號 電話:03-273-0900 客服中心電話:0800-365-996 Copyright© 2023 睿能創意股份有限公司 著作權所有,並保留一切權利。本車主手冊中任何部分未經睿能創意股份有限公司\n事前書面同意,不得以任何形式轉載、複製或拷貝。\n\n目錄\n\n目 錄 1. 在 您 上 路 之 前 5 1.1 如 何 使 用 本 手 冊 5 1.2 安 全 提 醒 5 1.2.1 每 次 騎 乘 前 應 檢 查 項 目 6 1.3 G o g o r o S m a r t s c o o t e r ® 簡 介 8 1.3.1 操 作 流 程 概 述 8 1.3.2 開 關 機 鑰 匙 9 1.3.2.1 機 械 式 鑰 匙 1 0 1.3.2.2 iQ S y s t e m ® 無 線 智 慧 鑰 匙 1 1 1.3.2.3 iQ S y s t e m ® 智 慧 鑰 匙 卡 1 2 1.3.2.4 G o g o r o S m a r t C oin 1 4 1.3.2.5 以 手 機 作 為 鑰 匙 1 5 1.3.3 啟 動 及 關 閉 馬 達 1 6 1.3.3.1 啟 動 馬 達 1 6 1.3.3.2 關 閉 馬 達 1 6 1.4 G o g o r o N e t w o r k ® 智 慧 電 池 簡 介 1 7 1.5 G o S t a tio n ® 電 池 交 換 站 簡 介 1 9 1.6 G o g o r o ® A p p 簡 介 2 0 1.7 iQ S y s t e m ® 簡 介 2 1 2. 認 識 您 的 S m a r t s c o o t e r ® 智 慧 電 動 機 車 2 2 2.1 C r o s s O v e r 各 部 位 名 稱 2 2 2.2 左 把 手 2 4 2.3 右 把 手 2 5 2.4 儀 表 板 2 7 2.5 C r o s s O v e r 系 列 座 墊 及 置 物 箱 操 作 方 式 2 9 2.5.1 開 啟 座 墊 下 置 物 箱 2 9 2.5.2 立 起 後 座 墊 2 9 2.5.3 拆 除 後 座 墊 3 0 2.5.4 關 閉 座 墊 下 置 物 箱 3 0 3. 準 備 上 路 3 1 3.1 機 械 式 鑰 匙 車 種 3 1 3.1.1 開 啟 系 統 電 源 並 解 鎖 龍 頭 3 1 3.1.2 關 閉 系 統 電 源 並 上 鎖 龍 頭 3 1 3.1.3 雙 重 防 盜 鎖 3 2 3.1.4 開 啟 座 墊 下 置 物 箱 3 3 3.1.5 休 眠 模 式 3 4 3.2 無 線 鑰 匙 車 種 3 5 3.2.1 iQ S y s t e m ® 無 線 智 慧 鑰 匙 3 6 3.2.1.1 開 啟 系 統 電 源 並 解 鎖 龍 頭 3 6 3.2.1.2 關 閉 系 統 電 源 及 上 鎖 龍 頭 3 6 3.2.1.3 開 啟 座 墊 下 置 物 箱 3 6 3.2.2 iQ S y s t e m ® 智 慧 鑰 匙 卡 3 7 3.2.2.1 iQ S y s t e m ® 智 慧 鑰 匙 卡 感 應 器 位 置 3 8 3.2.2.2 開 啟 系 統 電 源 並 解 鎖 龍 頭 3 9 3.2.2.3 關 閉 系 統 電 源 及 上 鎖 龍 頭 3 9 3.2.2.4 開 啟 座 墊 下 置 物 箱 3 9 3.2.3 G o g o r o S m a r t C oin 3 9 3.2.4 A p ple 錢 包 機 車 鑰 匙 4 0 3.2.5 手 機 做 為 遙 控 器 時 4 2 3.2.5.1 開 啟 系 統 電 源 並 解 鎖 龍 頭 4 2 3.2.5.2 關 閉 系 統 電 源 及 上 鎖 龍 頭 4 2\n\n3.2.5.3 雙 重 防 盜 鎖 4 2 3.2.5.4 開 啟 座 墊 下 置 物 箱 4 3 3.2.6 手 機 做 為 免 鑰 匙 智 慧 感 應 器 時 ( 智 慧 感 應 解 鎖 ) 4 4 3.2.6.1 開 啟 系 統 電 源 並 解 鎖 龍 頭 4 4 3.2.6.2 關 閉 系 統 電 源 4 4 3.2.7 倒 數 計 時 自 動 上 鎖 4 5 3.2.8 快 速 關 機 組 合 鍵 4 5 3.2.9 休 眠 模 式 4 6 3.2.1 0 支 援 A p ple Fin d M y n e t w o r k 4 7 4. 上 路 騎 乘 5 0 4.1 預 估 剩 餘 電 量 可 行 駛 里 程 5 0 4.2 取 車 及 架 車 5 1 4.3 啟 動 及 關 閉 馬 達 5 2 4.3.1 雙 重 防 盜 鎖 5 2 4.3.2 啟 動 馬 達 5 3 4.3.2.1 標 準 啟 動 程 序 5 3 4.3.2.2 快 速 啟 動 程 序 ( 一 踢 即 行 ) 5 3 4.3.3 關 閉 馬 達 5 4 4.3.3.1 標 準 關 閉 程 序 5 4 4.3.3.2 緊 急 關 閉 程 序 5 4 4.3.4 傾 倒 斷 電 保 護 5 5 4.4 前 進 及 後 退 5 6 4.4.1 電 子 油 門 5 6 4.4.2 電 子 倒 車 油 門 5 6 4.4.3 方 向 燈 自 動 關 閉 功 能 5 7 4.5 減 速 及 停 止 5 8 4.5.1 S B S 同 步 煞 車 系 統 5 8 4.5.2 A B S 防 鎖 死 煞 車 系 統 5 8 4.5.3 緊 急 煞 車 警 示 系 統 ( E S S ) 5 9 4.5.4 電 能 回 充 5 9 4.6 動 力 模 式 6 0 4.6.1 競 速 模 式 6 0 4.6.2 智 慧 模 式 6 0 4.6.3 低 電 量 模 式 6 1 4.6.4 高 / 低 溫 保 護 模 式 6 2 4.6.5 馬 達 堵 轉 保 護 6 3 4.7 進 階 功 能 6 4 4.7.1 AVA S 低 速 警 告 音 6 4 4.7.2 安 全 提 示 功 能 6 4 4.7.3 T P M S 胎 內 式 胎 壓 偵 測 器 6 5 4.7.3.1 設 定 胎 壓 警 示 值 6 5 4.7.3.2 於 儀 表 板 讀 取 胎 壓 數 值 6 5 4.7.3.3 於 G o g o r o ® A p p 讀 取 胎 壓 數 值 6 6 4.7.3.4 儀 表 板 警 示 訊 息 6 6 4.7.3.4 G o g o r o ® A p p 警 示 訊 息 6 7 4.7.4 性 能 提 升 服 務 方 案 6 9 4.7.5 賽 道 碼 錶 模 式 7 0 4.7.6 TC S 循 跡 防 滑 系 統 7 2 4.7.6.1 TC S 標 準 模 式 7 2 4.7.6.2 TC S 進 階 模 式 7 2 4.7.7 定 速 巡 航 7 4 4.7.8 省 力 牽 車 模 式 7 5 4.7.9 騎 乘 模 式 選 擇 7 6\n\n4.7.9.1 VIVA MIX SUPERFST ESC 野巡者騎乘模式 76 5. 補充電力 76 5.1 在 GoStation® 電池交換站交換電池 77 5.1.1 用 Gogoro® App 尋找站點 77 5.1.2 用 GoStation® 電池交換站的螢幕尋找其他站點 78 5.1.3 交換電池 79 5.1.4 身心障礙電池交換服務 81 5.2 對 Gogoro Network® 智慧電池充電 82 6. 使用 Gogoro® App 83 6.1 下載及安裝 Gogoro® App 83 6.2 將手機與 Smartscooter® 智慧電動機車配對連線 84 7. 保養維護 85 7.1 日常清潔與維護 85 7.2 Gogoro CrossOver 系列定期檢查與保養週期 86 7.3 服務據點 87 8. 附錄:其他依法令應聲明事項 88 8.1 NCC 國家通訊傳播委員會 88 8.2 行政院環保署 88 8.3 經濟部能源局 88\n\n1. 在您上路之前 5\n\n歡迎加入 Gogoro 車主的行列!我們將帶領您正確與安全地使用 Smartscooter® 智慧電動機\n車的每個功能。為了確保您的行車安全,騎乘前請務必詳細閱讀本手冊,並確認自己隨時符合 下列要件:\n- 持有政府所核發且仍有效的本車種駕駛執照。\n- 具備安全及正確的騎乘技巧及生理及心理狀況。\n- 完全了解 Smartscooter® 智慧電動機車的操作方法及應變措施。\n- 完全了解本手冊的各項資訊,包括但不限於相關說明、注意事項及警告資訊等。\n任何操作與保養的問題,請洽 Gogoro 客服中心(0800-365-996)。祝您擁有安全愉快的騎乘\n體驗!\n\n1.1 如何使用本手冊\n\n本手冊以下列圖示來表示特別重要的資訊:\n警告:表示需特別注意,否則可能導致人身傷害或機件損壞。 注意:表示使用時需加留意之處。\n\nGogoro 服 ...

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
md_header_splits = markdown_splitter.split_documents(data)
md_header_splits
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       1 headers_to_split_on = [
#       2     ("#", "Header 1"),
#       3     ("##", "Header 2"),
#       4     ("###", "Header 3"),
#       5 ]
#       7 markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
# ----> 8 md_header_splits = markdown_splitter.split_documents(data)
#       9 md_header_splits
#
# AttributeError: 'MarkdownHeaderTextSplitter' object has no attribute 'split_documents'
